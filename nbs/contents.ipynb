# %% [markdown]
# ## Contents
# This is a repository of Key Stage 3 (KS3) computing lessons
# ### [01 - Encryption vs Hashing](01_encryption_vs_hashing.ipynb)
# ### [10 - Developer Guide](developer_guide.ipynb)
